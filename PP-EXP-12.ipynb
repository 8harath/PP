# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.plot([1, 2, 3], [4, 5, 6])
ax1.set_title('Line Plot')

ax2.bar([1, 2, 3], [6, 5, 4])
ax2.set_title('Bar Plot')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
sizes = [30, 45, 25]

plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart Example')
plt.show()

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('iris')
sns.pairplot(df, hue='species')
plt.show()

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('tips')
sns.violinplot(x='day', y='total_bill', data=df)
plt.title('Violin Plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'Year': [2018, 2019, 2020, 2021],
                   'Sales': [100, 150, 200, 250]})

plt.fill_between(df['Year'], df['Sales'], color='skyblue', alpha=0.4)
plt.plot(df['Year'], df['Sales'], color='Slateblue')
plt.title('Area Chart')
plt.show()

# %%
import `folium`

m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)
folium.CircleMarker(location=[28.6139, 77.2090], radius=10, popup='Delhi', color='blue').add_to(m)

m.save('map.html')
print("Map saved as 'map.html'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import folium
#       3 m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)
#       4 folium.CircleMarker(location=[28.6139, 77.2090], radius=10, popup='Delhi', color='blue').add_to(m)
#
# ModuleNotFoundError: No module named 'folium'
